# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
path = "nc_files/T2M_hourly_2019.nc"
t2m = xr.open_dataset(path)
t2m['T2M'][0,:,:].plot()

# %%
path = "nc_files/H500_hourly_2019.nc"
t2m = xr.open_dataset(path)
t2m['H500'][0,:,:].plot()

# %%
t2m
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 101, lon: 576, time: 24)
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01T00:30:00 ... 2019-01-01T23:30:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 ... -41.5 -41.0 -40.5 -40.0
# Data variables:
#     H500     (time, lat, lon) float32 ...
# Attributes:
#     CDI:                               Climate Data Interface version 1.9.8 (...
#     history:                           Fri Apr 03 16:46:41 2020: cdo cat tmp1...
#     Conventions:                       CF-1
#     History:                           Original file generated: Wed Jan 30 22...
#     Comment:                           GMAO filename: d5124_m2_jan10.tavg1_2d...
#     Filename:                          MERRA2_400.tavg1_2d_slv_Nx.20190101.nc4
#     Institution:                       NASA Global Modeling and Assimilation ...
# ...
