# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
path = "nc_files/LWGAB_hourly_2019.nc"
t2m = xr.open_dataset(path)
t2m['LWGAB'][0,:,:].plot()

# %%
t2m['time']
# Out:
# <xarray.DataArray 'time' (time: 8760)>
# array(['2019-01-01T00:30:00.000000000', '2019-01-01T01:30:00.000000000',
#        '2019-01-01T02:30:00.000000000', ..., '2019-12-31T21:30:00.000000000',
#        '2019-12-31T22:30:00.000000000', '2019-12-31T23:30:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01T00:30:00 ... 2019-12-31T23:30:00
# Attributes:
#     standard_name:  time
#     long_name:      time
#     axis:           T
